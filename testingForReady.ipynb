# %%
#Useful functions @racu10

import pandas as pd
import numpy as np
import overpy
import overpass
import folium
from osmapi import OsmApi
import math
import geopy
import geopy.distance
import time
import unicodedata

MyApi = OsmApi()
apiOverPass = overpass.API()
apiOverPy =  overpy.Overpass()
import functions as fun

# %%
T = fun.getAllBarrisBCNPoligonBox()

# %%
csvData = fun.getDataOfCsv('alldata/sexebarris/opendata_2015_ine-ine01.csv')
for index, row in csvData.iterrows():
    csvData.set_value(index, 'Barris', fun.removeIntInxString(csvData.get_value(index, 'Barris'), '.').lower())
    csvData.set_value(index, 'Dte.', index+1)
print csvData
# Out:
#     Dte.                                        Barris   TOTAL    Homes  \
# 0      1                                      el raval  47.142   25.689
# 1      2                                el barri gòtic  15.484    8.133
# 2      3                                la barceloneta  15.032    7.498
# 3      4         sant pere, santa caterina i la ribera  22.457   11.216
# 4      5                                 el fort pienc  31.543   14.817
# 5      6                            la sagrada família  51.097   23.440
# 6      7                        la dreta de l'eixample  43.556   20.092
# 7      8               l'antiga esquerra de l'eixample  41.664   19.217
# 8      9                la nova esquerra de l'eixample  57.665   26.733
# 9     10                                   sant antoni  38.033   17.918
# 10    11                  el poble sec - parc montjuïc  40.208   19.785
# 11    12      la marina del prat vermell - zona franca   1.125  570.000
# 12    13                             la marina de port  30.232   14.593
# 13    14                         la font de la guatlla  10.366    4.885
# 14    15                                   hostafrancs  15.747    7.534
# 15    16                                    la bordeta  18.378    8.675
# 16    17                                 sants - badal  24.014   11.276
# 17    18                                         sants  40.687   19.245
# 18    19                                     les corts  46.000   21.368
# 19    20                    la maternitat i sant ramon  23.817   11.128
# 20    21                                     pedralbes  11.713    5.475
# 21    22         vallvidrera, el tibidabo i les planes   4.602    2.245
# 22    23                                        sarrià  24.641   11.483
# 23    24                               les tres torres  16.498    7.713
# 24    25                    sant gervasi - la bonanova  25.246   11.587
# 25    26                        sant gervasi - galvany  46.708   21.056
# 26    27                          el putxet i el farró  29.139   13.248
# 27    28                     vallcarca i els penitents  15.492    7.193
# 28    29                                       el coll   7.349    3.455
# 29    30                                      la salut  13.227    6.060
# ..   ...                                           ...     ...      ...
# 43    44                 vilapicina i la torre llobeta  25.451   11.680
# 44    45                                         porta  24.240   11.327
# 45    46                           el turó de la peira  15.389    7.089
# 46    47                                   can peguera   2.275    1.088
# 47    48                                  la guineueta  15.099    7.033
# 48    49                                     canyelles   6.953    3.332
# 49    50                                  les roquetes  15.398    7.442
# 50    51                                        verdun  12.225    5.657
# 51    52                                la prosperitat  25.979   12.357
# 52    53                              la trinitat nova   7.332    3.510
# 53    54                                    torre baró   2.727    1.374
# 54    55                              ciutat meridiana  10.245    5.091
# 55    56                                      vallbona   1.335  656.000
# 56    57                             la trinitat vella  10.059    5.225
# 57    58                                 baró de viver   2.482    1.209
# 58    59                                 el bon pastor  12.554    6.281
# 59    60                                   sant andreu  56.503   26.619
# 60    61                                    la sagrera  28.887   13.495
# 61    62                      el congrés i els indians  14.043    6.390
# 62    63                                         navas  21.966   10.184
# 63    64                    el camp de l'arpa del clot  38.178   17.911
# 64    65                                       el clot  26.933   12.937
# 65    66             el parc i la llacuna del poblenou  14.708    7.108
# 66    67                 la vila olímpica del poblenou   9.326    4.570
# 67    68                                   el poblenou  33.437   16.265
# 68    69  diagonal mar i el front marítim del poblenou  13.369    6.523
# 69    70                         el besòs i el maresme  22.834   11.587
# 70    71                       provençals del poblenou  20.161    9.741
# 71    72                      sant martí de provençals  25.975   12.174
# 72    73                           la verneda i la pau  28.738   13.681
#
#       Dones
# 0    21.453
# 1     7.351
# 2     7.534
# 3    11.241
# 4    16.726
# 5    27.657
# 6    23.464
# 7    22.447
# 8    30.932
# 9    20.115
# 10   20.423
# 11  555.000
# 12   15.639
# 13    5.481
# 14    8.213
# 15    9.703
# 16   12.738
# 17   21.442
# 18   24.632
# 19   12.689
# 20    6.238
# 21    2.357
# 22   13.158
# 23    8.785
# 24   13.659
# 25   25.652
# 26   15.891
# 27    8.299
# 28    3.894
# 29    7.167
# ..      ...
# 43   13.771
# 44   12.913
# 45    8.300
# 46    1.187
# 47    8.066
# 48    3.621
# 49    7.956
# 50    6.568
# 51   13.622
# 52    3.822
# 53    1.353
# 54    5.154
# 55  679.000
# 56    4.834
# 57    1.273
# 58    6.273
# 59   29.884
# 60   15.392
# 61    7.653
# 62   11.782
# 63   20.267
# 64   13.996
# 65    7.600
# 66    4.756
# 67   17.172
# 68    6.846
# 69   11.247
# 70   10.420
# 71   13.801
# 72   15.057
#
# [73 rows x 5 columns]

# %%
allData = fun.getDataOfCsv('alldata/sexebarris/opendata_2015_ine-ine01.csv')
allData
state_data = []
for x in T:
    points = []
    for point in T[x]:
        points.append(tuple([point[1], point[0]]))
        state_data.append({x : 3.0})

        
startLoc = [41.388790,2.158990]
map = folium.Map(location=startLoc)
map.choropleth(geo_path='barris.geojson', 
             data=csvData,             
             columns=['Dte.', 'Homes'],
             key_on='feature.properties.cartodb_id',
             fill_color='YlGn', 
             fill_opacity=0.7, 
             line_opacity=0.3,
             threshold_scale = [100, 200, 300, 400, 550, 700],
             legend_name="Poblacio Homes")


map.save("testing4ready3.html")

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
