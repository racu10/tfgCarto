# %%
import functions as fun

# %%
T = fun.getDatabase('barris', 'geojson','data/barris.geojson', '',True, 0, 1, 'neighbourhood')      
map = fun.mapCreation(41.388790,2.158990)
cluster = fun.mapWithMarkerCluster(map, "Restaurants Barcelona")

# %%
maxP = len(T[1])
porc = 0
x = 0
maxSee = 10
for barri in T[1]: #all barcelona polygons
    if x < maxSee:
        data = fun.getDatabaseFromOSM('restaurantes', 'amenity', True, True, T[1][barri],'restaurant')
        for d in data:
            fun.mapAddMarkerToCluster(cluster, d["geometry"][0], d["geometry"][1], 'glyphicon-glass', 'green', "")
        porc +=1
        print ( porc * 1.0 / min(maxP, maxSee) * 1.0) * 100
    x += 1
# Out:
# 10.0
# 20.0
# 30.0
# 40.0
# 50.0
# 60.0
# 70.0
# 80.0
# 90.0
# 100.0

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
